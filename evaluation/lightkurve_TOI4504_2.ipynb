# %%
from lightkurve import TessLightCurve
import numpy as np
# %matplotlib inline

lc88 = TessLightCurve.read('TIC349972412_sector_10_88.fits')
# lc = TessLightCurve.read('TIC349972412_sector_0_31.fits')
lc88.flux = np.mean(lc88.flux, axis=(1, 2))  # Average the flux values across the additional dimensions
lc88 = lc88.remove_outliers()
lc88 = lc88.flatten()
lc88.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import numpy as np
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 5 lc88 = TessLightCurve.read('TIC349972412_sector_10_88.fits')
#       6 # lc = TessLightCurve.read('TIC349972412_sector_0_31.fits')
#       7 lc88.flux = np.mean(lc88.flux, axis=(1, 2))  # Average the flux values across the additional dimensions
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\lightkurve\lightcurve.py:3299, in TessLightCurve.read(cls, *args, **kwargs)
#    3297 if kwargs.get("format") is None:
#    3298     kwargs["format"] = "tess"
# -> 3299 return super().read(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\astropy\timeseries\sampled.py:411, in TimeSeries.read(self, filename, time_column, time_format, time_scale, format, *args, **kwargs)
#     366 """
#     367 Read and parse a file and returns a `astropy.timeseries.TimeSeries`.
#     368
#    (...)
#     407 -----
#     408 """
#     409 try:
#     410     # First we try the readers defined for the BinnedTimeSeries class
# --> 411     return super().read(filename, *args, format=format, **kwargs)
#     413 except TypeError:
#     414     # Otherwise we fall back to the default Table readers
#     416     if time_column is None:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\astropy\table\connect.py:62, in TableRead.__call__(self, *args, **kwargs)
#      59 units = kwargs.pop("units", None)
#      60 descriptions = kwargs.pop("descriptions", None)
# ---> 62 out = self.registry.read(cls, *args, **kwargs)
#      64 # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#      65 # guaranteed to be the same as the desired output `cls`.  If so,
#      66 # try coercing to desired class without copying (io.registry.read
#      67 # would normally do a copy).  The normal case here is swapping
#      68 # Table <=> QTable.
#      69 if cls is not out.__class__:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\astropy\io\registry\core.py:221, in UnifiedInputRegistry.read(self, cls, format, cache, *args, **kwargs)
#     218         kwargs.update({"filename": path})
#     220 reader = self.get_reader(format, cls)
# --> 221 data = reader(*args, **kwargs)
#     223 if not isinstance(data, cls):
#     224     # User has read with a subclass where only the parent class is
#     225     # registered.  This returns the parent class, so try coercing
#     226     # to desired subclass.
#     227     try:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\lightkurve\io\tess.py:33, in read_tess_lightcurve(filename, flux_column, quality_bitmask)
#       8 def read_tess_lightcurve(
#       9     filename, flux_column="pdcsap_flux", quality_bitmask="default"
#      10 ):
#      11     """Returns a TESS `~lightkurve.lightcurve.LightCurve`.
#      12
#      13     Parameters
#    (...)
#      31         See the `~lightkurve.utils.TessQualityFlags` class for details on the bitmasks.
#      32     """
# ---> 33     lc = read_generic_lightcurve(filename, flux_column=flux_column, time_format="btjd")
#      35     # Filter out poor-quality data
#      36     # NOTE: Unfortunately Astropy Table masking does not yet work for columns
#      37     # that are Quantity objects, so for now we remove poor-quality data instead
#      38     # of masking. Details: https://github.com/astropy/astropy/issues/10119
#      39     quality_mask = TessQualityFlags.create_quality_mask(
#      40         quality_array=lc["quality"], bitmask=quality_bitmask
#      41     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\lightkurve\io\generic.py:42, in read_generic_lightcurve(filename, time_column, flux_column, flux_err_column, quality_column, cadenceno_column, centroid_col_column, centroid_row_column, time_format, ext)
#      40     hdulist, to_close_hdul = filename, False # Allow HDUList to be passed
#      41 else:
# ---> 42     hdulist = fits.open(filename)
#      44 try:
#      45     # Raise an exception if the requested extension is invalid
#      46     if isinstance(ext, str):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\astropy\io\fits\hdu\hdulist.py:224, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#     221 if not name:
#     222     raise ValueError(f"Empty filename: {name!r}")
# --> 224 return HDUList.fromfile(
#     225     name,
#     226     mode,
#     227     memmap,
#     228     save_backup,
#     229     cache,
#     230     lazy_load_hdus,
#     231     ignore_missing_simple,
#     232     use_fsspec=use_fsspec,
#     233     fsspec_kwargs=fsspec_kwargs,
#     234     decompress_in_memory=decompress_in_memory,
#     235     **kwargs,
#     236 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\astropy\io\fits\hdu\hdulist.py:488, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     469 @classmethod
#     470 def fromfile(
#     471     cls,
#    (...)
#     479     **kwargs,
#     480 ):
#     481     """
#     482     Creates an `HDUList` instance from a file-like object.
#     483
#    (...)
#     486     documentation for details of the parameters accepted by this method).
#     487     """
# --> 488     return cls._readfrom(
#     489         fileobj=fileobj,
#     490         mode=mode,
#     491         memmap=memmap,
#     492         save_backup=save_backup,
#     493         cache=cache,
#     494         ignore_missing_simple=ignore_missing_simple,
#     495         lazy_load_hdus=lazy_load_hdus,
#     496         **kwargs,
#     497     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\astropy\io\fits\hdu\hdulist.py:1170, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#    1167 if fileobj is not None:
#    1168     if not isinstance(fileobj, _File):
#    1169         # instantiate a FITS file object (ffo)
# -> 1170         fileobj = _File(
#    1171             fileobj,
#    1172             mode=mode,
#    1173             memmap=memmap,
#    1174             cache=cache,
#    1175             use_fsspec=use_fsspec,
#    1176             fsspec_kwargs=fsspec_kwargs,
#    1177             decompress_in_memory=decompress_in_memory,
#    1178         )
#    1179     # The Astropy mode is determined by the _File initializer if the
#    1180     # supplied mode was None
#    1181     mode = fileobj.mode
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\astropy\io\fits\file.py:218, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs, decompress_in_memory)
#     216     self._open_fileobj(fileobj, mode, overwrite)
#     217 elif isinstance(fileobj, (str, bytes)):
# --> 218     self._open_filename(fileobj, mode, overwrite)
#     219 else:
#     220     self._open_filelike(fileobj, mode, overwrite)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\astropy\io\fits\file.py:651, in _File._open_filename(self, filename, mode, overwrite)
#     648 ext = os.path.splitext(self.name)[1]
#     650 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 651     self._file = open(self.name, IO_FITS_MODES[mode])
#     652     self.close_on_error = True
#     654 # Make certain we're back at the beginning of the file
#     655 # BZ2File does not support seek when the file is open for writing, but
#     656 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'TIC349972412_sector_10_88.fits'
