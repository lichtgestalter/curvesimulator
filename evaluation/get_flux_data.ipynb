# %% [markdown]
# ## Check available lightcurves and pixeldata. Visualize and download them

# %%
import lightkurve as lk
from lightkurve import search_targetpixelfile

# %matplotlib inline

# %%
# search_result = lk.search_lightcurve('TIC349972412', cadence='long')
# search_result = lk.search_lightcurve('TIC349972412', author='TESS-SPOC', cadence='long')
search_result = lk.search_lightcurve('TIC349972412')
# search_result = lk.search_lightcurve('TIC349972412', sector=89)
# search_result = lk.search_lightcurve('TIC349972412', author='QLP', cadence='long')
# search_result = lk.search_lightcurve('TOI-4504', author='Tess', cadence='long')
# lc_collection = search_result.download_all()
# lc_collection.plot();
search_result
# Out:
# SearchResult containing 123 data products.
#
#  #     mission     year       author      exptime target_name distance
#                                              s                 arcsec
# --- -------------- ---- ----------------- ------- ----------- --------
#   0 TESS Sector 33 2020              SPOC      20   349972412      0.0
#   1 TESS Sector 30 2020              SPOC      20   349972412      0.0
#   2 TESS Sector 31 2020              SPOC      20   349972412      0.0
#   3 TESS Sector 29 2020              SPOC      20   349972412      0.0
#   4 TESS Sector 32 2020              SPOC      20   349972412      0.0
#   5 TESS Sector 27 2020              SPOC     120   349972412      0.0
#   6 TESS Sector 33 2020              SPOC     120   349972412      0.0
#   7 TESS Sector 28 2020              SPOC     120   349972412      0.0
#   8 TESS Sector 31 2020              SPOC     120   349972412      0.0
#   9 TESS Sector 30 2020              SPOC     120   349972412      0.0
# ...

# %%
# search_result = lk.search_lightcurve('TIC349972412')
search_result = lk.search_lightcurve('TIC349972412', author=['SPOC', 'TESS-SPOC'], sector=31)
lc_collection = search_result.download_all()
lc_collection.plot();
search_result
# Out:
# SearchResult containing 3 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 31 2020      SPOC      20   349972412      0.0
#   1 TESS Sector 31 2020      SPOC     120   349972412      0.0
#   2 TESS Sector 31 2020 TESS-SPOC     600   349972412      0.0

# %%
# search_result = lk.search_lightcurve('TIC349972412')
search_result = lk.search_lightcurve('TIC349972412', author=['QLP'], sector=31)
lc_collection = search_result.download_all()
lc_collection.plot();
search_result
# Out:
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 31 2020    QLP     600   349972412      0.0

# %%
# search_result = lk.search_lightcurve('TIC349972412')
# search_result = lk.search_lightcurve('TIC349972412', sector=6)
# search_result = lk.search_lightcurve('TIC349972412', author=['QLP', 'GSFC-ELEANOR-LITE', 'TASOC', 'TGLC'], sector=6)
search_result = lk.search_lightcurve('TIC349972412', author=['QLP', 'TGLC'], sector=6)
# normalized: 'TGLC', 'QLP'
lc_collection = search_result.download_all()
lc_collection.plot();
search_result
# Out:
# SearchResult containing 2 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 06 2018    QLP    1800   349972412      0.0
#   1 TESS Sector 06 2018   TGLC    1800   349972412      0.0

# %%
# search_result = lk.search_lightcurve('TIC349972412')
# search_result = lk.search_lightcurve('TIC349972412', sector=6)
# search_result = lk.search_lightcurve('TIC349972412', author=['QLP', 'GSFC-ELEANOR-LITE', 'TASOC', 'TGLC'], sector=6)
search_result = lk.search_lightcurve('TIC349972412', author=['GSFC-ELEANOR-LITE', 'TASOC'], sector=6)
# search_result = lk.search_lightcurve('TIC349972412', author=['QLP', 'TGLC'], sector=6)
# normalized: 'TGLC', 'QLP'
lc_collection = search_result.download_all()
lc_collection.plot();
search_result
# Out:
# C:\Users\ulsc\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightkurve\collections.py:263: LightkurveWarning: Some but not all of the light curves in the collection appear to be normalized. You may wish to use `normalize=True` to ensure all are normalized.
#   warnings.warn(
# SearchResult containing 3 data products.
#
#  #     mission     year       author      exptime target_name distance
#                                              s                 arcsec
# --- -------------- ---- ----------------- ------- ----------- --------
#   0 TESS Sector 06 2018 GSFC-ELEANOR-LITE    1800   349972412      0.0
#   1 TESS Sector 06 2018             TASOC    1800   349972412      0.0
#   2 TESS Sector 06 2018             TASOC    1800   349972412      0.0

# %%
# search_result = lk.search_lightcurve('TIC349972412')
# search_result = lk.search_lightcurve('TIC349972412', sector=6)
# search_result = lk.search_lightcurve('TIC349972412', author=['QLP', 'GSFC-ELEANOR-LITE', 'TASOC', 'TGLC'], sector=6)
search_result = lk.search_lightcurve('TIC349972412', author=['GSFC-ELEANOR-LITE'], sector=6)
# search_result = lk.search_lightcurve('TIC349972412', author=['QLP', 'TGLC'], sector=6)
# normalized: 'TGLC', 'QLP'
lc_collection = search_result.download_all()
lc_collection.plot();
search_result
# Out:
# SearchResult containing 1 data products.
#
#  #     mission     year       author      exptime target_name distance
#                                              s                 arcsec
# --- -------------- ---- ----------------- ------- ----------- --------
#   0 TESS Sector 06 2018 GSFC-ELEANOR-LITE    1800   349972412      0.0

# %%
# Search for target pixel files
# https://lightkurve.github.io/lightkurve/reference/api/lightkurve.search_targetpixelfile.html#lightkurve.search_targetpixelfile
# search = search_targetpixelfile("TIC 349972412", sector=[28, 31, 34, 37, 61, 64, 67, 87, 88, 89])
search = search_targetpixelfile("TIC 349972412", sector=89)
# search = search_targetpixelfile("TIC 349972412", author="SPOC", sector=[28, 31, 34, 37, 64, 67])
search
# Out:
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 89 2025   SPOC     120   349972412      0.0

# %%
search = search_targetpixelfile("TIC 349972412")
search
# Out:
# SearchResult containing 53 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 31 2020      SPOC      20   349972412      0.0
#   1 TESS Sector 32 2020      SPOC      20   349972412      0.0
#   2 TESS Sector 30 2020      SPOC      20   349972412      0.0
#   3 TESS Sector 29 2020      SPOC      20   349972412      0.0
#   4 TESS Sector 33 2020      SPOC      20   349972412      0.0
#   5 TESS Sector 31 2020      SPOC     120   349972412      0.0
#   6 TESS Sector 33 2020      SPOC     120   349972412      0.0
#   7 TESS Sector 30 2020      SPOC     120   349972412      0.0
#   8 TESS Sector 29 2020      SPOC     120   349972412      0.0
#   9 TESS Sector 28 2020      SPOC     120   349972412      0.0
#  10 TESS Sector 27 2020      SPOC     120   349972412      0.0
# ...

# %%
# Search for target pixel files
# search = search_targetpixelfile("TIC 349972412", author="SPOC", sector=28)
search = search_targetpixelfile("TIC 349972412", sector=[28, 31, 34, 37, 64, 67, 87, 88, 89])
tpf = search.download_all()

# Save each target pixel file as a .fits file
for i, file in enumerate(tpf):
    filename = f"TIC349972412_sector_{i}_{file.sector}.fits"
    file.to_fits(filename)
    print(f"Saved: {filename}")

# %%
pixelfile = search_targetpixelfile("TIC 349972412", author="SPOC", sector=[88]).download()

# %%
pixelfile.plot(frame=1)
# Out:
# <Axes: title={'center': 'Target ID: 349972412, Cadence: 1773143'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
pixelfile.plot(aperture_mask='pipeline');

# %%
lc = pixelfile.to_lightcurve(aperture_mask='pipeline').remove_outliers()

# %%
lc.plot()
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
lc_flattened = lc.flatten()

# %%
lc_flattened.plot()
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>
