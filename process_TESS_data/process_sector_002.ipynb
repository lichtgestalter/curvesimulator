# %% [markdown]
# # Processing TESS sector 2 data for TOI4504

# %%
# %matplotlib inline
from process_TESS_data.process_flux_data import *
path = '../research/star_systems/TOI-4504/lightkurve/'

# %%
full_path = path+"2/2_TGLC_1800.csv"
df = csv2df(full_path)
df = tesstime2bjd(df)
plot_this(df.time, [df.flux], ["flux"], title="Original data")
df
# Out:
#               time      flux  flux_err
# 0     2.458354e+06  1.002287       NaN
# 1     2.458354e+06  1.000515       NaN
# 2     2.458354e+06  0.998066       NaN
# 3     2.458354e+06  1.000481       NaN
# 4     2.458354e+06  1.000525       NaN
# ...            ...       ...       ...
# 1191  2.458381e+06  1.000849       NaN
# 1192  2.458381e+06  0.998622       NaN
# 1193  2.458381e+06  0.999176       NaN
# 1194  2.458381e+06  1.000859       NaN
# 1195  2.458381e+06  1.001017       NaN
#
# [1196 rows x 3 columns]

# %%
median = median_flux(df)
df = scale_flux(df, 1/median)
plot_this(df.time, [df.flux], ["flux"], title="Normalized to median=1")
df
# Out:
#               time      flux  flux_err
# 0     2.458354e+06  1.002272       NaN
# 1     2.458354e+06  1.000501       NaN
# 2     2.458354e+06  0.998052       NaN
# 3     2.458354e+06  1.000466       NaN
# 4     2.458354e+06  1.000511       NaN
# ...            ...       ...       ...
# 1191  2.458381e+06  1.000835       NaN
# 1192  2.458381e+06  0.998607       NaN
# 1193  2.458381e+06  0.999161       NaN
# 1194  2.458381e+06  1.000845       NaN
# 1195  2.458381e+06  1.001002       NaN
#
# [1196 rows x 3 columns]

# %%
df2csv(df, full_path[:-4]+"_p.csv")
